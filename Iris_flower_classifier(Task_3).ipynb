# %% [markdown]
# <a href="https://colab.research.google.com/github/raumyadip/CODSOFT/blob/main/Iris_flower_classifier(Task_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('/content/IRIS.csv')
ds
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
ds.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
ds.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
ds['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# This Dataset does not  have any Null Values

# %%
ds.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
ds.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# ...

# %% [markdown]
# Data Analyst using EDA

# %%
ds['sepal_length'].hist()
# Out:
# <Axes: >

# %%
ds['sepal_width'].hist()
# Out:
# <Axes: >

# %%
ds['petal_length'].hist()
# Out:
# <Axes: >

# %%
ds['petal_width'].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Data Analysis using pairplot**

# %%
sns.pairplot(ds,hue='species')

# %%
colors=['red','blue','green']
species=['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x=ds[ds["species"] == species[i]]
    plt.scatter(x['sepal_length'],x['sepal_width'],c=colors[i],label=species[i])
    plt.xlabel('sepal_length')
    plt.ylabel('sepal_width')
    plt.legend()

# %%
for i in range(3):
    x=ds[ds["species"] == species[i]]
    plt.scatter(x['petal_length'],x['petal_width'],c=colors[i],label=species[i])
    plt.xlabel('petal_length')
    plt.ylabel('petal_width')
    plt.legend()

# %%
for i in range(3):
    x=ds[ds["species"] == species[i]]
    plt.scatter(x['sepal_width'],x['petal_width'],c=colors[i],label=species[i])
    plt.xlabel('sepal_width')
    plt.ylabel('petal_width')
    plt.legend()

# %%
ds.corr()
# Out:
# <ipython-input-18-31b754434382>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ds.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
corr = ds.corr()
fig, ax = plt.subplots(figsize=(6,5))
sns.heatmap(corr, annot=True, ax=ax,cmap='coolwarm')
# Out:
# <ipython-input-19-ceefd9878d18>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = ds.corr()
# <Axes: >

# %% [markdown]
# Selecting the dependent and Indepedent Variables

# %%
X=ds[['sepal_length','sepal_width','petal_length','petal_width']]
y=ds[['species']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
print(x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 106           4.9          2.5           4.5          1.7  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# ...

# %%
print(y)
# Out:
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
print(X_train)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 17            5.1          3.5           1.4          0.3
# 42            4.4          3.2           1.3          0.2
# 18            5.7          3.8           1.7          0.3
# 146           6.3          2.5           5.0          1.9
# 114           5.8          2.8           5.1          2.4
# ..            ...          ...           ...          ...
# 70            5.9          3.2           4.8          1.8
# 132           6.4          2.8           5.6          2.2
# 33            5.5          4.2           1.4          0.2
# 109           7.2          3.6           6.1          2.5
# 139           6.9          3.1           5.4          2.1
#
# [105 rows x 4 columns]

# %%
print(y_train)
# Out:
#              species
# 17       Iris-setosa
# 42       Iris-setosa
# 18       Iris-setosa
# 146   Iris-virginica
# 114   Iris-virginica
# ..               ...
# 70   Iris-versicolor
# 132   Iris-virginica
# 33       Iris-setosa
# 109   Iris-virginica
# 139   Iris-virginica
#
# [105 rows x 1 columns]

# %%
print(X_test)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 88            5.6          3.0           4.1          1.3
# 72            6.3          2.5           4.9          1.5
# 20            5.4          3.4           1.7          0.2
# 16            5.4          3.9           1.3          0.4
# 147           6.5          3.0           5.2          2.0
# 140           6.7          3.1           5.6          2.4
# 113           5.7          2.5           5.0          2.0
# 23            5.1          3.3           1.7          0.5
# 12            4.8          3.0           1.4          0.1
# 68            6.2          2.2           4.5          1.5
# 39            5.1          3.4           1.5          0.2
# 130           7.4          2.8           6.1          1.9
# 34            4.9          3.1           1.5          0.1
# 112           6.8          3.0           5.5          2.1
# 55            5.7          2.8           4.5          1.3
# ...

# %%
print(y_test)
# Out:
#              species
# 88   Iris-versicolor
# 72   Iris-versicolor
# 20       Iris-setosa
# 16       Iris-setosa
# 147   Iris-virginica
# 140   Iris-virginica
# 113   Iris-virginica
# 23       Iris-setosa
# 12       Iris-setosa
# 68   Iris-versicolor
# 39       Iris-setosa
# 130   Iris-virginica
# 34       Iris-setosa
# 112   Iris-virginica
# 55   Iris-versicolor
# 25       Iris-setosa
# 82   Iris-versicolor
# 48       Iris-setosa
# 81   Iris-versicolor
# 77   Iris-versicolor
# 100   Iris-virginica
# 80   Iris-versicolor
# 14       Iris-setosa
# 131   Iris-virginica
# 86   Iris-versicolor
# 118   Iris-virginica
# 56   Iris-versicolor
# 54   Iris-versicolor
# 97   Iris-versicolor
# 143   Iris-virginica
# 125   Iris-virginica
# 98   Iris-versicolor
# 73   Iris-versicolor
# 144   Iris-virginica
# 21       Iris-setosa
# 3        Iris-setosa
# 59   Iris-versicolor
# 119   Iris-virginica
# 84   Iris-versicolor
# 7        Iris-setosa
# 41       Iris-setosa
# 57   Iris-versicolor
# ...

# %% [markdown]
# **We will use KNN to classify the species data**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
k = 3
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Accuracy of KNN data model

# %%
accuracy = knn.score(X_test, y_test)*100
print("Accuracy:", accuracy)
# Out:
# Accuracy: 95.55555555555556

# %% [markdown]
# Now let's give a new data point to testing the model

# %%
new_data_point = [[5.1, 3.2, 1.8, 0.3]]
predicted_class = knn.predict(new_data_point)
print("Predicted class for the new data point:", predicted_class)
# Out:
# Predicted class for the new data point: ['Iris-virginica']

# %% [markdown]
# **now we can also use logistic Regression for classify the data model**

# %%
from sklearn.linear_model import LogisticRegression
logistic_regression = LogisticRegression()
logistic_regression.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# **By using Logistic Regression we can get more accuracy in this model**

# %%
accuracy = logistic_regression.score(X_test, y_test)*100
print("Logistic Regression Accuracy:", accuracy)
# Out:
# Logistic Regression Accuracy: 97.77777777777777

# %% [markdown]
# **Testing data using new data points, and also it give same predicted output like KNN**

# %%
new_data_point = [[5.1, 3.2, 1.8, 0.3]]
predicted_class= logistic_regression.predict(new_data_point)
print("Predicted class for the new data point using Logistic Regression:", predicted_class)
# Out:
# Predicted class for the new data point using Logistic Regression: ['Iris-virginica']
